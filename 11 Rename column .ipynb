# %% [markdown]
# import pandas as pd

# %%
import pandas as pd 
df_exams=pd.read_csv('C:/Users/hp/Downloads/StudentsPerformance.csv')
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %% [markdown]
# # Rename column

# %%
# rename column and overwrite the values of data frame 
df_exams.rename(columns={'gender':'Gender'})
# Out:
#      Gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
# rename column and overwrite the values of data frame

# %%
# reaname multiple columns and update the data frame with inplace argument
df_exams.rename(columns={'gender':'Gender','math score':'Math Score','reading score':'Reading Score','writing score':'Writing Score'},
               inplace=True)
df_exams
# Out:
#      Gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  Math Score  Reading Score  Writing Score
# ...

# %%
#show the data frame
df_exams
# Out:
#      Gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  Math Score  Reading Score  Writing Score
# ...

# %% [markdown]
# # RENAME INDEX

# %%
# rename index 0,1 and 2 amd update the data frame 
df_exams.rename(index={0:'A',1:'B',2:'C'}, inplace=True)

# %%
# show first 3 rows 
df_exams.head(3)
# Out:
#    Gender race/ethnicity parental level of education     lunch  \
# A  female        group B           bachelor's degree  standard
# B  female        group C                some college  standard
# c  female        group B             master's degree  standard
#
#   test preparation course  Math Score  Reading Score  Writing Score
# A                    none          72             72             74
# B               completed          69             90             88
# c                    none          90             95             93
