# %%
import pandas as pd

# %%
#reading and showing the data frane 
import pandas as pd 
df_exams=pd.read_csv('C:/Users/hp/Downloads/StudentsPerformance.csv')
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# ..                      ...         ...            ...            ...
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
# [1000 rows x 8 columns]

# %% [markdown]
# # 1 create  index

# %%
import numpy as np 
import random

# %%
#creating non repetative value for index 
new_index=np.arange(0,1000)

# %%
#shuffling the index 
random.shuffle(new_index)

# %%
#create a nw column with new index
df_exams['new_index']=new_index
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# ..                      ...         ...            ...            ...
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
#      new_index
# 0          361
# 1            0
# 2          155
# 3          423
# 4          771
# ..         ...
# 995        135
# 996        250
# 997        225
# 998        747
# 999        100
#
# [1000 rows x 9 columns]

# %% [markdown]
# #  set index

# %%
#set new_index column as index 
df_exams.set_index('new_index', inplace=True)
df_exams
# Out:
#            gender race/ethnicity parental level of education         lunch  \
# new_index
# 361        female        group B           bachelor's degree      standard
# 0          female        group C                some college      standard
# 155        female        group B             master's degree      standard
# 423          male        group A          associate's degree  free/reduced
# 771          male        group C                some college      standard
# ...           ...            ...                         ...           ...
# 135        female        group E             master's degree      standard
# 250          male        group C                 high school  free/reduced
# 225        female        group C                 high school  free/reduced
# 747        female        group D                some college      standard
# 100        female        group D                some college  free/reduced
#
#           test preparation course  math score  reading score  writing score
# new_index
# 361                          none          72             72             74
# 0                       completed          69             90             88
# 155                          none          90             95             93
# 423                          none          47             57             44
# 771                          none          76             78             75
# ...                           ...         ...            ...            ...
# 135                     completed          88             99             95
# 250                          none          62             55             55
# 225                     completed          59             71             65
# 747                     completed          68             78             77
# 100                          none          77             86             86
#
# [1000 rows x 8 columns]

# %% [markdown]
# # Sort index

# %%
df_exams.sort_index()
# Out:
#            gender race/ethnicity parental level of education         lunch  \
# new_index
# 0          female        group C                some college      standard
# 1            male        group A                 high school      standard
# 2          female        group A            some high school      standard
# 3          female        group B           bachelor's degree      standard
# 4          female        group D                some college      standard
# ...           ...            ...                         ...           ...
# 995          male        group A           bachelor's degree      standard
# 996          male        group C          associate's degree  free/reduced
# 997        female        group D           bachelor's degree  free/reduced
# 998          male        group B          associate's degree  free/reduced
# 999          male        group A            some high school      standard
#
#           test preparation course  math score  reading score  writing score
# new_index
# 0                       completed          69             90             88
# 1                            none          71             74             64
# 2                       completed          59             85             80
# 3                       completed          65             81             81
# 4                            none          65             70             71
# ...                           ...         ...            ...            ...
# 995                     completed          87             84             87
# 996                     completed          78             81             82
# 997                          none          63             73             78
# 998                          none          57             56             57
# 999                     completed          47             49             49
#
# [1000 rows x 8 columns]

# %%
# sort descending by index  
df_exams.sort_index(ascending=False,inplace=True)
df_exams
# Out:
#            gender race/ethnicity parental level of education         lunch  \
# new_index
# 999          male        group A            some high school      standard
# 998          male        group B          associate's degree  free/reduced
# 997        female        group D           bachelor's degree  free/reduced
# 996          male        group C          associate's degree  free/reduced
# 995          male        group A           bachelor's degree      standard
# ...           ...            ...                         ...           ...
# 4          female        group D                some college      standard
# 3          female        group B           bachelor's degree      standard
# 2          female        group A            some high school      standard
# 1            male        group A                 high school      standard
# 0          female        group C                some college      standard
#
#           test preparation course  math score  reading score  writing score
# new_index
# 999                     completed          47             49             49
# 998                          none          57             56             57
# 997                          none          63             73             78
# 996                     completed          78             81             82
# 995                     completed          87             84             87
# ...                           ...         ...            ...            ...
# 4                            none          65             70             71
# 3                       completed          65             81             81
# 2                       completed          59             85             80
# 1                            none          71             74             64
# 0                       completed          69             90             88
#
# [1000 rows x 8 columns]
