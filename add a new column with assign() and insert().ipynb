# %%
import pandas as pd

# %%
#reading the csv file 
import pandas as pd 
df_exams=pd.read_csv('C:/Users/hp/Downloads/StudentsPerformance.csv')
df_exams.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %% [markdown]
# # adding a new column

# %% [markdown]
# ### 1.1 assign()

# %% [markdown]
# ####  when to use assign ?
# #### add multiple columns in a single line of code
# #### when u need to overwrite the values of an existing columns
# #### it returns a new object (a copy)with all the original columns in addidtion to new ones

# %%
import numpy as np

# %%
#craete random numbers for our new score columns 
score1 =np.random.randint(1,100, size=1000)
score2 =np.random.randint(1,100, size=1000)

# %%
# create a series using the random numbers 
series1 = pd.Series(score1, index=np.arange(0, 1000))
series2 = pd.Series(score2, index=np.arange(0, 1000))

# %%
# using assign () to add multiple columns 
df_exams=df_exams.assign(score1=series1,score2=series2)

# %%
#show the data frame 
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  score1  \
# 0                      none          72             72             74      19
# 1                 completed          69             90             88      77
# 2                      none          90             95             93      71
# 3                      none          47             57             44      26
# 4                      none          76             78             75       8
# ..                      ...         ...            ...            ...     ...
# 995               completed          88             99             95      74
# 996                    none          62             55             55      94
# 997               completed          59             71             65      40
# 998               completed          68             78             77      12
# 999                    none          77             86             86      86
#
#      score2
# 0        30
# 1        46
# 2        38
# 3         8
# 4        53
# ..      ...
# 995      57
# 996      78
# 997      59
# 998      89
# 999      50
#
# [1000 rows x 10 columns]

# %% [markdown]
# ## 1.2 insert()
#
# #### inserts a column at a specific position or index

# %%
#using index to add column at specific position 
df_exams.insert(1,'test', series1 )

# %%
#show data frame 
df_exams
# Out:
#      gender  test race/ethnicity parental level of education         lunch  \
# 0    female    19        group B           bachelor's degree      standard
# 1    female    77        group C                some college      standard
# 2    female    71        group B             master's degree      standard
# 3      male    26        group A          associate's degree  free/reduced
# 4      male     8        group C                some college      standard
# ..      ...   ...            ...                         ...           ...
# 995  female    74        group E             master's degree      standard
# 996    male    94        group C                 high school  free/reduced
# 997  female    40        group C                 high school  free/reduced
# 998  female    12        group D                some college      standard
# 999  female    86        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  score1  \
# 0                      none          72             72             74      19
# 1                 completed          69             90             88      77
# 2                      none          90             95             93      71
# 3                      none          47             57             44      26
# 4                      none          76             78             75       8
# ..                      ...         ...            ...            ...     ...
# 995               completed          88             99             95      74
# 996                    none          62             55             55      94
# 997               completed          59             71             65      40
# 998               completed          68             78             77      12
# 999                    none          77             86             86      86
#
#      score2
# 0        30
# 1        46
# 2        38
# 3         8
# 4        53
# ..      ...
# 995      57
# 996      78
# 997      59
# 998      89
# 999      50
#
# [1000 rows x 11 columns]
